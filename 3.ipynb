# %%
import pandas as pd 
import numpy as np
from matplotlib import pyplot as plt
from scipy import stats

# %%
import seaborn as sns

# %%
data=pd.read_csv('finail_2.csv')
data.head()
# Out:
#         تاریخ                                        آدرس  سن بنا  قیمت واحد  \
# 0  2024-08-14                          شهران بلوار كوهسار       5  104000000
# 1  2024-08-14                          شهران بلوار كوهسار       5  104000000
# 2  2024-08-14                         تهران نو فلكه چایچی      20   74285000
# 3  2024-08-14  انتهای همت غرب مروارید شهر خ شهید اردستانی       0   78651000
# 4  2024-08-14                        نیرو هوایی خ 30 متری      22   77142000
#
#       قیمت کل  tabaghe      code          addres  dastresi  tejary  ...  \
# 0  7800000000      2.0  10416222          شهران        4.0     2.0  ...
# 1  7800000000      2.0  10416222          شهران        4.0     2.0  ...
# 2  5200000000      3.0  10335838       تهران نو        NaN     NaN  ...
# 3  7000000000     13.0  10416220   شهرک راه آهن        4.0     0.0  ...
# 4  5400000000      3.0  10267636     نیرو هوایی        NaN     NaN  ...
#
# ...

# %%
sns.jointplot(data['قیمت واحد'],data['سن بنا'])
plt.show()

# %%
sns.jointplot(data['قیمت واحد'],data['tabaghe'])
plt.show()

# %%
plt.figure(figsize=(25,5))
sns.stripplot(data['tabaghe'],data['قیمت واحد'])
plt.show()

# %%
sns.jointplot(data['zone'],data['قیمت کل'])
plt.show()

# %%
plt.figure(figsize=(25,5))
sns.stripplot(data['zone'],data['قیمت کل'], size=3)
plt.show()

# %%
sns.jointplot(data['dastresi'],data['قیمت کل'])
plt.show()

# %%
sns.jointplot(data['tejary'],data['قیمت کل'])
plt.show()

# %%
sns.jointplot(data['farhangi_honary'],data['قیمت کل'])
plt.show()

# %%
sns.regplot(data['farhangi_honary'],data['قیمت کل'])
plt.show()

# %%
sns.regplot(data['tejary'],data['قیمت کل'])
plt.show()

# %%
sns.regplot(data['zone'],data['قیمت کل'])
plt.show()

# %%
sns.regplot(data['tabaghe'],data['قیمت واحد'])
plt.show()

# %%
sns.regplot(data['سن بنا'],data['قیمت واحد'])
plt.show()

# %%
sns.stripplot(data['انباری'],data['قیمت کل'], size=3)
plt.show()

# %%
sns.stripplot(data['خواب'],data['قیمت کل'], size=3)
plt.show()

# %% [raw]
# a=data[data['خواب']>30].index
# data.drop(index=(a),inplace=True)

# %%
sns.jointplot(data['خواب'],data['قیمت کل'],)
plt.show()

# %%
sns.regplot(data['خواب'],data['قیمت کل'],)
plt.show()

# %%
sns.stripplot(data['شمالی'],data['قیمت کل'], size=3)
sns.jointplot(data['شمالی'],data['قیمت کل'],)
plt.show()

# %%
sns.stripplot(data['جنوبی'],data['قیمت کل'], size=3)
sns.jointplot(data['جنوبی'],data['قیمت کل'],)
plt.show()

# %%
sns.stripplot(data['شرقی'],data['قیمت کل'], size=3)
sns.jointplot(data['شرقی'],data['قیمت کل'],)
plt.show()

# %%
sns.stripplot(data['غربی'],data['قیمت کل'], size=3)
sns.jointplot(data['غربی'],data['قیمت کل'],)
plt.show()

# %% [raw]
# ss=data[data['قیمت کل']>269000000000].index

# %% [raw]
# data.drop(index=ss,inplace=True)

# %%
plt.figure(figsize=(25,5))
sns.stripplot(data['آشپزخانه'],data['قیمت کل'], size=3)
plt.show()

# %%
plt.figure(figsize=(25,5))
sns.stripplot(data['کفپوش'],data['قیمت کل'], size=3)
plt.show()

# %%
plt.figure(figsize=(25,5))
sns.jointplot(data['زیربنا_y'],data['قیمت کل'],)
plt.show()
